# %%
#Importamos librerias
import pandas as pd
import numpy as np

# %%
#Cargo archivo
df = pd.read_csv("Exportaciones.csv")
df
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 0      alb  1997     primaryagr       93.3774       0.0143    0.2158
# 1      alb  1997      otherprim        0.0521       5.7779    0.0979
# 2      alb  1997         energy       12.8071       3.0441  195.5730
# 3      alb  1997      procfoods        0.8223       0.0041    0.0706
# 4      alb  1997     bevtobacco        0.0022       0.0003    0.0036
# ...    ...   ...            ...           ...          ...       ...
# 13198  zwe  2011        finance       15.7700       0.3200    0.2900
# 13199  zwe  2011      insurance        2.9000       0.0400    0.0300
# 13200  zwe  2011         obsict       18.5100       0.4300    0.3700
# 13201  zwe  2011      oconsumer        3.0600       0.0700    0.0800
# 13202  zwe  2011      oservices       12.1400       1.0900    0.6800
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
#Filtro a1
a1= df[df["iso3"] == "alb"]
a1
# Out:
#      iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 0     alb  1997     primaryagr       93.3774       0.0143    0.2158
# 1     alb  1997      otherprim        0.0521       5.7779    0.0979
# 2     alb  1997         energy       12.8071       3.0441  195.5730
# 3     alb  1997      procfoods        0.8223       0.0041    0.0706
# 4     alb  1997     bevtobacco        0.0022       0.0003    0.0036
# ...   ...   ...            ...           ...          ...       ...
# 9985  alb  2011        finance       18.4600       5.0100    2.7400
# 9986  alb  2011      insurance        1.9300       0.9500    0.3700
# 9987  alb  2011         obsict       12.1900       4.1700    1.1700
# 9988  alb  2011      oconsumer        4.7900       3.0200    0.4100
# 9989  alb  2011      oservices        0.5600       0.9600    0.0500
#
#       g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# 0         25.0267        0.3817      0.1455      0.9488  ...     0.0019
# ...

# %%
#Filtro 2
a2 = df[df["h_insurance"]> 0.5]
a2
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim   g_energy  \
# 29     arg  1997         energy      282.7920       1.9522  4426.8600
# 48     arg  1997   communcation       30.1041       0.1865    13.2494
# 49     arg  1997        finance      239.0100       0.9834   150.3820
# 50     arg  1997      insurance       33.6523       0.1945    18.3172
# 51     arg  1997         obsict      172.1130       1.8889   125.9700
# ...    ...   ...            ...           ...          ...        ...
# 13168  zmb  2011   distribution      370.6800     200.5300    72.9600
# 13171  zmb  2011        finance       25.2200      14.7300    12.0200
# 13172  zmb  2011      insurance        2.1500       1.2900     0.8900
# 13199  zwe  2011      insurance        2.9000       0.0400     0.0300
# 13202  zwe  2011      oservices       12.1400       1.0900     0.6800
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...
